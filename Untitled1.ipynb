# %%
#Dependencies
import pandas as pd
import json
from pandas.io.json import json_normalize
import os
import csv
from pprint import pprint

# %%
adopted_file="Ran/austin_adopted_201904.json"

# %%
adopted_json=pd.read_json(adopted_file)
adopted_json.head()
# Out:
#          id organization_id  \
# 0  50642555           TX920
# 1  50636718          TX2153
# 2  50636303          TX1219
# 3  50636302          TX1219
# 4  50635943           TX989
#
#                                                  url type species  \
# 0  https://www.petfinder.com/dog/fondue-50642555/...  Dog     Dog
# 1  https://www.petfinder.com/dog/clifford-5063671...  Dog     Dog
# 2  https://www.petfinder.com/dog/charley-50636303...  Dog     Dog
# 3  https://www.petfinder.com/dog/clementine-50636...  Dog     Dog
# 4  https://www.petfinder.com/dog/mattie-50635943/...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Great Pyrenees', 'secondary': Non...
# 1  {'primary': 'Plott Hound', 'secondary': None, ...
# 2  {'primary': 'Boxer', 'secondary': None, 'mixed...
# 3  {'primary': 'Boxer', 'secondary': None, 'mixed...
# 4  {'primary': 'Glen of Imaal Terrier', 'secondar...
#
# ...

# %%
adopted_json.dtypes
# Out:
# id                                      int64
# organization_id                        object
# url                                    object
# type                                   object
# species                                object
# breeds                                 object
# colors                                 object
# age                                    object
# gender                                 object
# size                                   object
# coat                                   object
# attributes                             object
# environment                            object
# tags                                   object
# name                                   object
# description                            object
# organization_animal_id                 object
# photos                                 object
# primary_photo_cropped                  object
# videos                                 object
# ...

# %%
adopted_json["organization_id"].unique()
# Out:
# array(['TX920', 'TX2153', 'TX1219', 'TX989', 'TX2137', 'IN393', 'TX1051',
#        'TX1701', 'TX1250', 'TX1913', 'TX34', 'TX1047', 'TX758', 'TX2480',
#        'TX1334', 'TX2269', 'TX1008', 'TX2165', 'TX2305', 'TX697',
#        'TX2426', 'TX142', 'TX1931', 'TX258', 'TX411', 'TX2270', 'TX2183',
#        'TX1364', 'TX2359', 'TX1372', 'TX170', 'TX1393', 'TX2358',
#        'TX1494', 'TX2042', 'TX2332', 'TX1049', 'TX1936', 'TX2134',
#        'TX2482', 'TX2083', 'TX2485', 'TX1607', 'TX2339', 'TX2004',
#        'TX937', 'TX359', 'TX1606', 'TX1584', 'TX2334', 'TX2467', 'TX1069',
#        'FL1720', 'TX2250', 'TX1870', 'TX1084', 'TX1388', 'TX2490',
#        'TX2417', 'TX562', 'TX2251', 'OK10', 'TX2486', 'TX1156', 'TX1279',
#        'TX933', 'TX1866', 'TX1309', 'TX778', 'TX128', 'TX1491', 'CO430',
#        'TX2433', 'TX1261', 'TX826', 'TX1402', 'TX1662', 'TX2484',
#        'TX2357', 'TX993', 'TX1588', 'TX953', 'TX2311', 'TX1985', 'TX734',
# ...

# %%
adoptable_file="Ran/tx_data_0220.json"

# %%
adoptable_json=pd.read_json(adoptable_file)
adoptable_json.head()
# Out:
#          id organization_id  \
# 0  50614898          TX2184
# 1  50614755          TX2184
# 2  50614759           TX487
# 3  50614756           TX236
# 4  50614729          TX1888
#
#                                                  url type species  \
# 0  https://www.petfinder.com/dog/simon-50614898/t...  Dog     Dog
# 1  https://www.petfinder.com/dog/scout-50614755/t...  Dog     Dog
# 2  https://www.petfinder.com/dog/a596096-50614759...  Dog     Dog
# 3  https://www.petfinder.com/dog/1114909-50614756...  Dog     Dog
# 4  https://www.petfinder.com/dog/june-jum-star-50...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Chihuahua', 'secondary': None, 'm...
# 1  {'primary': 'Collie', 'secondary': 'Chihuahua'...
# 2  {'primary': 'Parson Russell Terrier', 'seconda...
# 3  {'primary': 'Pit Bull Terrier', 'secondary': N...
# 4  {'primary': 'Poodle', 'secondary': None, 'mixe...
#
# ...

# %%
adopted_json["status_changed_at"].unique()
# Out:
# <DatetimeArray>
# ['2021-02-24 01:41:15+00:00', '2021-02-23 17:28:50+00:00',
#  '2021-02-23 16:58:24+00:00', '2021-02-23 19:50:37+00:00',
#  '2021-02-23 15:27:29+00:00', '2021-02-23 23:04:43+00:00',
#  '2021-02-21 23:53:36+00:00', '2021-02-21 22:06:55+00:00',
#  '2021-02-21 20:52:07+00:00', '2021-02-21 20:35:16+00:00',
#  ...
#  '2019-05-28 19:40:15+00:00', '2019-04-22 05:54:58+00:00',
#  '2019-04-18 21:46:53+00:00', '2019-05-22 18:23:44+00:00',
#  '2019-10-01 15:50:28+00:00', '2019-04-24 02:06:46+00:00',
#  '2020-02-08 05:22:52+00:00', '2019-10-11 11:34:29+00:00',
#  '2019-07-29 16:47:14+00:00', '2019-05-06 07:17:02+00:00']
# Length: 21549, dtype: datetime64[ns, UTC]

# %%
adoptable_json["status_changed_at"].unique()
# Out:
# <DatetimeArray>
# ['2021-02-21 06:23:44+00:00', '2021-02-21 06:11:19+00:00',
#  '2021-02-21 06:07:20+00:00', '2021-02-21 06:07:18+00:00',
#  '2021-02-21 05:45:34+00:00', '2021-02-21 05:45:33+00:00',
#  '2021-02-21 05:45:32+00:00', '2021-02-21 05:22:02+00:00',
#  '2021-02-21 05:07:13+00:00', '2021-02-21 05:07:12+00:00',
#  ...
#  '2020-02-22 22:37:55+00:00', '2020-02-22 22:41:18+00:00',
#  '2020-02-22 22:44:58+00:00', '2020-02-22 22:47:34+00:00',
#  '2020-02-22 22:49:32+00:00', '2020-02-22 22:52:07+00:00',
#  '2020-02-22 22:55:01+00:00', '2020-02-22 22:59:49+00:00',
#  '2020-02-22 23:01:56+00:00', '2010-06-11 07:02:58+00:00']
# Length: 11112, dtype: datetime64[ns, UTC]

# %%
adoptable_json["id"].unique()
# Out:
# array([50614898, 50614755, 50614759, ...,  5027078,  4224403,  3483368],
#       dtype=int64)

# %%
adopted_json["id"].unique()
# Out:
# array([50642555, 50636718, 50636303, ..., 44362283, 44362128, 44362066],
#       dtype=int64)

# %%
adoptable_json["id"].nunique()
# Out:
# 14556

# %%
adopted_json["id"].nunique()
# Out:
# 23606

# %%
austin_animal = adoptable_json.loc[adoptable_json["organization_id"]=='TX154']
austin_animal.head()
# Out:
#              id organization_id  \
# 11800  47696853           TX154
# 11948  47372888           TX154
# 12123  47115247           TX154
# 12159  47019713           TX154
# 12160  47019673           TX154
#
#                                                      url type species  \
# 11800  https://www.petfinder.com/cat/raven-special-ne...  Cat     Cat
# 11948  https://www.petfinder.com/cat/dahlia-47372888/...  Cat     Cat
# 12123  https://www.petfinder.com/dog/harley-bosco-471...  Dog     Dog
# 12159  https://www.petfinder.com/cat/cutie-pie-left-4...  Cat     Cat
# 12160  https://www.petfinder.com/cat/sweet-pea-right-...  Cat     Cat
#
#                                                   breeds  \
# 11800  {'primary': 'Domestic Short Hair', 'secondary'...
# 11948  {'primary': 'Domestic Short Hair', 'secondary'...
# 12123  {'primary': 'Boxer', 'secondary': None, 'mixed...
# 12159  {'primary': 'Domestic Short Hair', 'secondary'...
# ...

# %%
austin_animal["id"].nunique()
# Out:
# 17

# %%
austin_animal
# Out:
#              id organization_id  \
# 11800  47696853           TX154
# 11948  47372888           TX154
# 12123  47115247           TX154
# 12159  47019713           TX154
# 12160  47019673           TX154
# 12270  46813798           TX154
# 12271  46813738           TX154
# 12272  46813638           TX154
# 12273  46813422           TX154
# 13392  42437507           TX154
# 13405  42363264           TX154
# 13659  40619258           TX154
# 13830  38832447           TX154
# 14118  33972838           TX154
# 14127  33448947           TX154
# 14161  32525127           TX154
# 14449  20815219           TX154
#
#                                                      url type species  \
# 11800  https://www.petfinder.com/cat/raven-special-ne...  Cat     Cat
# 11948  https://www.petfinder.com/cat/dahlia-47372888/...  Cat     Cat
# 12123  https://www.petfinder.com/dog/harley-bosco-471...  Dog     Dog
# 12159  https://www.petfinder.com/cat/cutie-pie-left-4...  Cat     Cat
# ...
